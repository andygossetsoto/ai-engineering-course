# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role": "user", "content": "What is an okapi?"}]
)

answer = response.choices[0].message.content

print(answer)
# Out:
# An okapi is a unique mammal native to the dense rainforests of the Democratic Republic of Congo in Central Africa. It is closely related to the giraffe, despite its zebra-like striped markings on its legs. The okapi has a body shape similar to a giraffe's but much shorter, with a long neck (though not as long as a giraffe's), large ears, and a velvety dark brown or reddish coat. It is a herbivore, feeding on leaves, buds, grasses, ferns, fruits, and fungi. The okapi is a shy and elusive animal, often called the "forest giraffe," and was only known to the Western world in the early 20th century. Its scientific name is *Okapia johnstoni*.
