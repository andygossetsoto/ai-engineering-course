# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
from pprint import pprint
import gradio as gr
import json

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")

client = OpenAI()

# %% [markdown]
# ### Step 2: RAG Preparation

# %%
document = """
Andrea is an experienced Front End Engineer. She's based in Atlanta, Georgia. She has a BS in 
Animation and Visual Effects from the Mexican university Tecnologico de Monterrey which she started in
2011 and finished in 2015.

She's been a Front End Engineer since 2016 creating web applications and managing 
CMS across various industries. Proven team leader with a strong commitment to understanding business 
aspects for innovative solutions, showcasing skills in mentorship, continuous learning, and optimizing 
user experience through modern technologies.

Other career history:
2015: Intern at MetaCube as a 3D Digital Modeller for the Dia de Muertos movie
2016-2018: Front End Engineer at Base22
2018-2022: Senior Front End Engineer at Globant
    - Led a consulting team to develop two intranets alongside the client Realogy using Angular 7, NgRx, 
    Jasmine, and Apollo GraphQL, resulting in realtors benefiting from a centralized platform for 
    accessing their essential day-to-day tools.
    - Engineered an npm library with Node to seamlessly integrate a standardized theme across various 
    intranets and applications, improving consistency, efficiency, and fostering a more unified and 
    cohesive visual identity.
    - Collaborated with Stanley Black and Decker's team to enhance their Site Manager and Public API 
    intranets. Developed a comprehensive week-to-week action plan streamlining their development and 
    Scrum processes.
    - Mentored 3 peers at a time to facilitate their career advancement within their teams, providing 
    guidance and support.
    - Conducted thorough interviews with prospective candidates for seamless integration into the company.

2022-2023: Software Engineer at Twitter
    - Directed the front-end effort for the Semantic Core UI migration leveraging React.js, Typescript, 
    Javascript, and CSS enabling clients to efficiently gather insights for optimal ad promotion within 
    Twitter's internal platform.
    - Mentored and spearheaded a 5-person division within the TwST (Twitter Security Team) department, 
    fostering professional growth, team cohesion, and cross-functional collaboration to achieve key 
    departmental objectives.
    - Authored the Technical Design Document for the Semantic Core UI migration to accommodate new 
    implementations, enhance code quality, and improve maintainability to ensure an organized and 
    well-architectured development.

2023-Present: Senior Front End Engineer at Rooms To Go
    Improved website performance, streamlined content updates, and collaborated with cross-functional 
    teams to implement key features. Additionally led the front-end team, optimizing Agile processes 
    to enhance efficiency and delivery.
    - Spearheaded front-end artificial intelligence (AI) projects, enhancing customer engagement and 
    contributing to a 30 percent boost in sales revenue.
    - Migrated the main E-commerce webpage from React.js and MUI to Next.js, TypeScript, and Tailwind, 
    implementing a more efficient server-side solution that resulted in a 45% performance improvement, 
    enhancing the user experience.
    - Developed, updated, and revamped React.js components, Strapi schemas, and the organization's npm 
    library to streamline E-Commerce content updates, ensuring timely refreshes that featured weekly 
    sales and drove increased revenue.
    - Collaborated with the Content, UX and Marketing teams to gather and comprehend new requirements, 
    translating them into actionable tickets while assuming leadership responsibilities for their 
    implementation within the front-end team.


Technical Skills:
Javascript (ES6+), React.js, Typescript, Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress, 
Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo GraphQL, REST APIs, n8n, 
Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node, Scala, Strapi, IBM WCM, Liferay DXP, Git, Agile, 
Scrum, Kanban.

Languages:
English (fluent), Spanish (native), French (proficient).

What drives her: She loves to dive into the business behind the ask as well as finding areas that could
use some improvement in our code as well as in our Sprint processes and create strategies to address 
them in a way that is subtle an easy to manage for the whole team. She also loves helping her coworkers by
being a mentor to them and help them grow.

Her approach: Always thinking two steps ahead and thinking as a mentor.

Communication style:Friendly and accessible, thinking as a mentor.

Additional info:
- In 2008 Andrea was studying highshool abroad
- Andrea doesn't like cooking
- Andrea loves peaches, she likes them by themselves, on cakes, on jello,\
    with cinamon, etc.
- Andrea has loved singing since she was a kid, previously she only did it\
    in the shower but as she grew older she started doing it while driving and almost everywhere she\
    could.. Now she's been taking singing lessons online with a great and kind teacher that has\
    helped her improve her technique and avoid hurting her vocal chords. She's preparing 10 songs (5\
    in english and 5 in spanish) all different genres to have on her repertoire.
"""

# %%
import re


def split_text_into_chunks(
    text: str,
    max_chunk_size: int = 500,
    overlap: int = 50,
) -> list[str]:
    chunks = []
    start = 0

    while start < len(text):
        max_end = min(start + max_chunk_size, len(text))

        if max_end == len(text):
            chunks.append(text[start:].strip())
            break

        halfway = start + max_chunk_size // 2
        section = text[halfway:max_end]

        # Boundaries in priority order
        boundaries = [
            section.rfind("\n\n"),
            section.rfind("\n"),
        ]

        sentence_matches = list(re.finditer(r"[.!?](?=\s|$)", section))
        boundaries.append(
            sentence_matches[-1].end() if sentence_matches else -1
        )

        boundaries.append(section.rfind(" "))

        # Use the first boundary type that exists.
        cut = next((b for b in boundaries if b != -1), None)

        end = halfway + cut if cut is not None else max_end

        # Include the boundary character(s) for sentence/newline cuts.
        if cut is not None:
            if text[end:end + 2] == "\n\n":
                end += 2
            elif text[end:end + 1] == "\n":
                end += 1
            elif end < len(text) and text[end] in ".!?":
                end += 1

        chunks.append(text[start:end].strip())

        start = end - overlap

    return chunks

chunks = split_text_into_chunks(document, 100, 20)
print(f"Created {len(chunks)} chunks: \n")

for i, chunk in enumerate(chunks):
    print(f"--- Chunk {i + 1} | {len(chunk)} chars ---")
    print(chunk)
    print()
# Out:
# Created 82 chunks:
#
# --- Chunk 1 | 93 chars ---
# Andrea is an experienced Front End Engineer. She's based in Atlanta, Georgia. She has a BS in
#
# --- Chunk 2 | 91 chars ---
# a. She has a BS in
# Animation and Visual Effects from the Mexican university Tecnologico de
#
# --- Chunk 3 | 78 chars ---
# rsity Tecnologico de Monterrey which she started in
# 2011 and finished in 2015.
#
# --- Chunk 4 | 91 chars ---
# finished in 2015.
#
# She's been a Front End Engineer since 2016 creating web applications and
#
# --- Chunk 5 | 61 chars ---
# web applications and managing
# CMS across various industries.
#
# --- Chunk 6 | 89 chars ---
# various industries. Proven team leader with a strong commitment to understanding business
#
# --- Chunk 7 | 97 chars ---
# rstanding business
# aspects for innovative solutions, showcasing skills in mentorship, continuous
#
# --- Chunk 8 | 91 chars ---
# ntorship, continuous learning, and optimizing
# user experience through modern technologies.
#
# --- Chunk 9 | 99 chars ---
# dern technologies.
#
# Other career history:
# 2015: Intern at MetaCube as a 3D Digital Modeller for the
#
# --- Chunk 10 | 81 chars ---
# tal Modeller for the Dia de Muertos movie
# 2016-2018: Front End Engineer at Base22
#
# --- Chunk 11 | 66 chars ---
# Engineer at Base22
# 2018-2022: Senior Front End Engineer at Globant
#
# --- Chunk 12 | 93 chars ---
# Engineer at Globant
#     - Led a consulting team to develop two intranets alongside the client
#
# --- Chunk 13 | 51 chars ---
# alongside the client Realogy using Angular 7, NgRx,
#
# --- Chunk 14 | 92 chars ---
# g Angular 7, NgRx,
#     Jasmine, and Apollo GraphQL, resulting in realtors benefiting from a
#
# --- Chunk 15 | 94 chars ---
# rs benefiting from a centralized platform for
#     accessing their essential day-to-day tools.
#
# --- Chunk 16 | 87 chars ---
# l day-to-day tools.
#     - Engineered an npm library with Node to seamlessly integrate a
#
# --- Chunk 17 | 54 chars ---
# amlessly integrate a standardized theme across various
#
# --- Chunk 18 | 90 chars ---
# eme across various
#     intranets and applications, improving consistency, efficiency, and
#
# --- Chunk 19 | 80 chars ---
# ncy, efficiency, and fostering a more unified and
#     cohesive visual identity.
#
# --- Chunk 20 | 97 chars ---
# ve visual identity.
#     - Collaborated with Stanley Black and Decker's team to enhance their Site
#
# --- Chunk 21 | 59 chars ---
# o enhance their Site Manager and Public API
#     intranets.
#
# --- Chunk 22 | 89 chars ---
# API
#     intranets. Developed a comprehensive week-to-week action plan streamlining their
#
# --- Chunk 23 | 58 chars ---
# n streamlining their development and
#     Scrum processes.
#
# --- Chunk 24 | 95 chars ---
# Scrum processes.
#     - Mentored 3 peers at a time to facilitate their career advancement within
#
# --- Chunk 25 | 70 chars ---
# r advancement within their teams, providing
#     guidance and support.
#
# --- Chunk 26 | 96 chars ---
# idance and support.
#     - Conducted thorough interviews with prospective candidates for seamless
#
# --- Chunk 27 | 50 chars ---
# didates for seamless integration into the company.
#
# --- Chunk 28 | 58 chars ---
# into the company.
#
# 2022-2023: Software Engineer at Twitter
#
# --- Chunk 29 | 90 chars ---
# Engineer at Twitter
#     - Directed the front-end effort for the Semantic Core UI migration
#
# --- Chunk 30 | 53 chars ---
# ic Core UI migration leveraging React.js, Typescript,
#
# --- Chunk 31 | 95 chars ---
# ct.js, Typescript,
#     Javascript, and CSS enabling clients to efficiently gather insights for
#
# --- Chunk 32 | 81 chars ---
# gather insights for optimal ad promotion within
#     Twitter's internal platform.
#
# --- Chunk 33 | 94 chars ---
# internal platform.
#     - Mentored and spearheaded a 5-person division within the TwST (Twitter
#
# --- Chunk 34 | 98 chars ---
# in the TwST (Twitter Security Team) department,
#     fostering professional growth, team cohesion,
#
# --- Chunk 35 | 70 chars ---
# owth, team cohesion, and cross-functional collaboration to achieve key
#
# --- Chunk 36 | 97 chars ---
# ion to achieve key
#     departmental objectives.
#     - Authored the Technical Design Document for
#
# --- Chunk 37 | 69 chars ---
# Design Document for the Semantic Core UI migration to accommodate new
#
# --- Chunk 38 | 93 chars ---
# to accommodate new
#     implementations, enhance code quality, and improve maintainability to
#
# --- Chunk 39 | 81 chars ---
# e maintainability to ensure an organized and
#     well-architectured development.
#
# --- Chunk 40 | 74 chars ---
# tured development.
#
# 2023-Present: Senior Front End Engineer at Rooms To Go
#
# --- Chunk 41 | 99 chars ---
# neer at Rooms To Go
#     Improved website performance, streamlined content updates, and collaborated
#
# --- Chunk 42 | 80 chars ---
# es, and collaborated with cross-functional
#     teams to implement key features.
#
# --- Chunk 43 | 84 chars ---
# lement key features. Additionally led the front-end team, optimizing Agile processes
#
# --- Chunk 44 | 59 chars ---
# ng Agile processes
#     to enhance efficiency and delivery.
#
# --- Chunk 45 | 96 chars ---
# iency and delivery.
#     - Spearheaded front-end artificial intelligence (AI) projects, enhancing
#
# --- Chunk 46 | 92 chars ---
# projects, enhancing customer engagement and
#     contributing to a 30 percent boost in sales
#
# --- Chunk 47 | 97 chars ---
# rcent boost in sales revenue.
#     - Migrated the main E-commerce webpage from React.js and MUI to
#
# --- Chunk 48 | 54 chars ---
# React.js and MUI to Next.js, TypeScript, and Tailwind,
#
# --- Chunk 49 | 97 chars ---
# ipt, and Tailwind,
#     implementing a more efficient server-side solution that resulted in a 45%
#
# --- Chunk 50 | 81 chars ---
# at resulted in a 45% performance improvement,
#     enhancing the user experience.
#
# --- Chunk 51 | 99 chars ---
# he user experience.
#     - Developed, updated, and revamped React.js components, Strapi schemas, and
#
# --- Chunk 52 | 97 chars ---
# Strapi schemas, and the organization's npm
#     library to streamline E-Commerce content updates,
#
# --- Chunk 53 | 67 chars ---
# rce content updates, ensuring timely refreshes that featured weekly
#
# --- Chunk 54 | 58 chars ---
# at featured weekly
#     sales and drove increased revenue.
#
# --- Chunk 55 | 92 chars ---
# increased revenue.
#     - Collaborated with the Content, UX and Marketing teams to gather and
#
# --- Chunk 56 | 48 chars ---
# teams to gather and comprehend new requirements,
#
# --- Chunk 57 | 89 chars ---
# new requirements,
#     translating them into actionable tickets while assuming leadership
#
# --- Chunk 58 | 93 chars ---
# assuming leadership responsibilities for their
#     implementation within the front-end team.
#
# --- Chunk 59 | 98 chars ---
# e front-end team.
#
#
# Technical Skills:
# Javascript (ES6+), React.js, Typescript, Next.js, Angular 7,
#
# --- Chunk 60 | 56 chars ---
# Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress,
#
# --- Chunk 61 | 91 chars ---
# Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo
#
# --- Chunk 62 | 98 chars ---
# UI, Tailwind, Apollo GraphQL, REST APIs, n8n,
# Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node,
#
# --- Chunk 63 | 85 chars ---
# , Gulp, Grunt, Node, Scala, Strapi, IBM WCM, Liferay DXP, Git, Agile,
# Scrum, Kanban.
#
# --- Chunk 64 | 87 chars ---
# e,
# Scrum, Kanban.
#
# Languages:
# English (fluent), Spanish (native), French (proficient).
#
# --- Chunk 65 | 98 chars ---
# ench (proficient).
#
# What drives her: She loves to dive into the business behind the ask as well as
#
# --- Chunk 66 | 96 chars ---
# d the ask as well as finding areas that could
# use some improvement in our code as well as in our
#
# --- Chunk 67 | 70 chars ---
# de as well as in our Sprint processes and create strategies to address
#
# --- Chunk 68 | 86 chars ---
# ategies to address
# them in a way that is subtle an easy to manage for the whole team.
#
# --- Chunk 69 | 59 chars ---
# for the whole team. She also loves helping her coworkers by
#
# --- Chunk 70 | 62 chars ---
# ng her coworkers by
# being a mentor to them and help them grow.
#
# --- Chunk 71 | 91 chars ---
# nd help them grow.
#
# Her approach: Always thinking two steps ahead and thinking as a mentor.
#
# --- Chunk 72 | 86 chars ---
# nking as a mentor.
#
# Communication style:Friendly and accessible, thinking as a mentor.
#
# --- Chunk 73 | 83 chars ---
# nking as a mentor.
#
# Additional info:
# - In 2008 Andrea was studying highshool abroad
#
# --- Chunk 74 | 91 chars ---
# ng highshool abroad
# - Andrea doesn't like cooking
# - Andrea loves peaches, she likes them by
#
# --- Chunk 75 | 74 chars ---
# s, she likes them by themselves, on cakes, on jello,    with cinamon, etc.
#
# --- Chunk 76 | 93 chars ---
# with cinamon, etc.
# - Andrea has loved singing since she was a kid, previously she only did it
#
# --- Chunk 77 | 95 chars ---
# y she only did it    in the shower but as she grew older she started doing it while driving and
#
# --- Chunk 78 | 53 chars ---
# it while driving and almost everywhere she    could..
#
# --- Chunk 79 | 95 chars ---
# where she    could.. Now she's been taking singing lessons online with a great and kind teacher
#
# --- Chunk 80 | 93 chars ---
# eat and kind teacher that has    helped her improve her technique and avoid hurting her vocal
#
# --- Chunk 81 | 92 chars ---
# id hurting her vocal chords. She's preparing 10 songs (5    in english and 5 in spanish) all
#
# --- Chunk 82 | 64 chars ---
# nd 5 in spanish) all different genres to have on her repertoire.

# %%
#Generate embeddings for all chunks
response = client.embeddings.create(
    model ="text-embedding-3-small",
    input = chunks
)
embeddings = [item.embedding for item in response.data]

#Verify embeddings
print(f"Generated {len(embeddings)} embeddings")
print(f"Each embedding has {len(embeddings[0])} dimensions")
# Out:
# Generated 82 embeddings
# Each embedding has 1536 dimensions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

reduced = TSNE(n_components=2, random_state=42, perplexity=min(30, len(embeddings)-1)).fit_transform(np.array(embeddings))
labels = KMeans(n_clusters=2, random_state=42).fit_predict(np.array(embeddings))

plt.figure(figsize=(8,6))
plt.scatter(reduced[:,0], reduced[:, 1], c=labels, cmap="bwr", alpha=0.7, s=50)
for i, (x,y) in enumerate(reduced):
    plt.annotate(str(i), (x,y), fontsize=7, alpha=0.6)
plt.title("Chunk Embeddings (t-SNE, 2 Clusters)")
plt.tight_layout()
plt.show()

# %%
#Initialize ChromaDB and Store Vectors

import chromadb

#initialize ChromaDB client (persistent storage)
chroma_client = chromadb.PersistentClient(path="./chroma_db_twin")

#initialize ChromaDB client (in-memory   storage)
#chroma_client = chromadb.Client()

collection = chroma_client.get_or_create_collection(name="netflix_culture")

#Emtoy the collection before adding new data (for testint purposes in regular projects you don't need this functionality)
if collection.get()["ids"]:
    collection.delete(collection.get()["ids"])

pprint(collection.get())
# Out:
# {'data': None,
#  'documents': [],
#  'embeddings': None,
#  'ids': [],
#  'included': ['metadatas', 'documents'],
#  'metadatas': [],
#  'uris': None}

# %%
#Prepare data for storage
ids = [f"chunk_{i}" for i in range(len(chunks))]
metadatas = [{"source": "netflix_culture_pdf", "chunk_index": i} for i in range(len(chunks))]

#Adding data to ChromaDB
collection.add(
    ids=ids,
    embeddings=embeddings,
    documents=chunks,
    metadatas=metadatas
)

pprint(collection.get(include=["documents", "embeddings"]))
# Out:
# {'data': None,
#  'documents': ["Andrea is an experienced Front End Engineer. She's based in "
#                'Atlanta, Georgia. She has a BS in',
#                'a. She has a BS in \n'
#                'Animation and Visual Effects from the Mexican university '
#                'Tecnologico de',
#                'rsity Tecnologico de Monterrey which she started in\n'
#                '2011 and finished in 2015.',
#                'finished in 2015.\n'
#                '\n'
#                "She's been a Front End Engineer since 2016 creating web "
#                'applications and',
#                'web applications and managing \nCMS across various industries.',
#                'various industries. Proven team leader with a strong '
#                'commitment to understanding business',
#                'rstanding business \n'
#                'aspects for innovative solutions, showcasing skills in '
#                'mentorship, continuous',
#                'ntorship, continuous learning, and optimizing \n'
#                'user experience through modern technologies.',
#                'dern technologies.\n'
#                '\n'
#                'Other career history:\n'
#                '2015: Intern at MetaCube as a 3D Digital Modeller for the',
#                'tal Modeller for the Dia de Muertos movie\n'
#                '2016-2018: Front End Engineer at Base22',
#                'Engineer at Base22\n'
#                '2018-2022: Senior Front End Engineer at Globant',
#                'Engineer at Globant\n'
#                '    - Led a consulting team to develop two intranets alongside '
#                'the client',
#                'alongside the client Realogy using Angular 7, NgRx,',
#                'g Angular 7, NgRx, \n'
#                '    Jasmine, and Apollo GraphQL, resulting in realtors '
#                'benefiting from a',
#                'rs benefiting from a centralized platform for \n'
#                '    accessing their essential day-to-day tools.',
#                'l day-to-day tools.\n'
#                '    - Engineered an npm library with Node to seamlessly '
#                'integrate a',
#                'amlessly integrate a standardized theme across various',
#                'eme across various \n'
#                '    intranets and applications, improving consistency, '
#                'efficiency, and',
#                'ncy, efficiency, and fostering a more unified and \n'
#                '    cohesive visual identity.',
#                've visual identity.\n'
#                "    - Collaborated with Stanley Black and Decker's team to "
#                'enhance their Site',
#                'o enhance their Site Manager and Public API \n    intranets.',
#                'API \n'
#                '    intranets. Developed a comprehensive week-to-week action '
#                'plan streamlining their',
#                'n streamlining their development and \n    Scrum processes.',
#                'Scrum processes.\n'
#                '    - Mentored 3 peers at a time to facilitate their career '
#                'advancement within',
#                'r advancement within their teams, providing \n'
#                '    guidance and support.',
#                'idance and support.\n'
#                '    - Conducted thorough interviews with prospective '
#                'candidates for seamless',
#                'didates for seamless integration into the company.',
#                'into the company.\n\n2022-2023: Software Engineer at Twitter',
#                'Engineer at Twitter\n'
#                '    - Directed the front-end effort for the Semantic Core UI '
#                'migration',
#                'ic Core UI migration leveraging React.js, Typescript,',
#                'ct.js, Typescript, \n'
#                '    Javascript, and CSS enabling clients to efficiently gather '
#                'insights for',
#                'gather insights for optimal ad promotion within \n'
#                "    Twitter's internal platform.",
#                'internal platform.\n'
#                '    - Mentored and spearheaded a 5-person division within the '
#                'TwST (Twitter',
#                'in the TwST (Twitter Security Team) department, \n'
#                '    fostering professional growth, team cohesion,',
#                'owth, team cohesion, and cross-functional collaboration to '
#                'achieve key',
#                'ion to achieve key \n'
#                '    departmental objectives.\n'
#                '    - Authored the Technical Design Document for',
#                'Design Document for the Semantic Core UI migration to '
#                'accommodate new',
#                'to accommodate new \n'
#                '    implementations, enhance code quality, and improve '
#                'maintainability to',
#                'e maintainability to ensure an organized and \n'
#                '    well-architectured development.',
#                'tured development.\n'
#                '\n'
#                '2023-Present: Senior Front End Engineer at Rooms To Go',
#                'neer at Rooms To Go\n'
#                '    Improved website performance, streamlined content updates, '
#                'and collaborated',
#                'es, and collaborated with cross-functional \n'
#                '    teams to implement key features.',
#                'lement key features. Additionally led the front-end team, '
#                'optimizing Agile processes',
#                'ng Agile processes \n    to enhance efficiency and delivery.',
#                'iency and delivery.\n'
#                '    - Spearheaded front-end artificial intelligence (AI) '
#                'projects, enhancing',
#                'projects, enhancing customer engagement and \n'
#                '    contributing to a 30 percent boost in sales',
#                'rcent boost in sales revenue.\n'
#                '    - Migrated the main E-commerce webpage from React.js and '
#                'MUI to',
#                'React.js and MUI to Next.js, TypeScript, and Tailwind,',
#                'ipt, and Tailwind, \n'
#                '    implementing a more efficient server-side solution that '
#                'resulted in a 45%',
#                'at resulted in a 45% performance improvement, \n'
#                '    enhancing the user experience.',
#                'he user experience.\n'
#                '    - Developed, updated, and revamped React.js components, '
#                'Strapi schemas, and',
#                "Strapi schemas, and the organization's npm \n"
#                '    library to streamline E-Commerce content updates,',
#                'rce content updates, ensuring timely refreshes that featured '
#                'weekly',
#                'at featured weekly \n    sales and drove increased revenue.',
#                'increased revenue.\n'
#                '    - Collaborated with the Content, UX and Marketing teams to '
#                'gather and',
#                'teams to gather and comprehend new requirements,',
#                'new requirements, \n'
#                '    translating them into actionable tickets while assuming '
#                'leadership',
#                'assuming leadership responsibilities for their \n'
#                '    implementation within the front-end team.',
#                'e front-end team.\n'
#                '\n'
#                '\n'
#                'Technical Skills:\n'
#                'Javascript (ES6+), React.js, Typescript, Next.js, Angular 7,',
#                'Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress,',
#                'Jasmine, Cypress, \n'
#                'Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, '
#                'Tailwind, Apollo',
#                'UI, Tailwind, Apollo GraphQL, REST APIs, n8n, \n'
#                'Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node,',
#                ', Gulp, Grunt, Node, Scala, Strapi, IBM WCM, Liferay DXP, Git, '
#                'Agile, \n'
#                'Scrum, Kanban.',
#                'e, \n'
#                'Scrum, Kanban.\n'
#                '\n'
#                'Languages:\n'
#                'English (fluent), Spanish (native), French (proficient).',
#                'ench (proficient).\n'
#                '\n'
#                'What drives her: She loves to dive into the business behind '
#                'the ask as well as',
#                'd the ask as well as finding areas that could\n'
#                'use some improvement in our code as well as in our',
#                'de as well as in our Sprint processes and create strategies to '
#                'address',
#                'ategies to address \n'
#                'them in a way that is subtle an easy to manage for the whole '
#                'team.',
#                'for the whole team. She also loves helping her coworkers by',
#                'ng her coworkers by\n'
#                'being a mentor to them and help them grow.',
#                'nd help them grow.\n'
#                '\n'
#                'Her approach: Always thinking two steps ahead and thinking as '
#                'a mentor.',
#                'nking as a mentor.\n'
#                '\n'
#                'Communication style:Friendly and accessible, thinking as a '
#                'mentor.',
#                'nking as a mentor.\n'
#                '\n'
#                'Additional info:\n'
#                '- In 2008 Andrea was studying highshool abroad',
#                'ng highshool abroad\n'
#                "- Andrea doesn't like cooking\n"
#                '- Andrea loves peaches, she likes them by',
#                's, she likes them by themselves, on cakes, on jello,    with '
#                'cinamon, etc.',
#                'with cinamon, etc.\n'
#                '- Andrea has loved singing since she was a kid, previously she '
#                'only did it',
#                'y she only did it    in the shower but as she grew older she '
#                'started doing it while driving and',
#                'it while driving and almost everywhere she    could..',
#                "where she    could.. Now she's been taking singing lessons "
#                'online with a great and kind teacher',
#                'eat and kind teacher that has    helped her improve her '
#                'technique and avoid hurting her vocal',
#                "id hurting her vocal chords. She's preparing 10 songs (5    in "
#                'english and 5 in spanish) all',
#                'nd 5 in spanish) all different genres to have on her '
#                'repertoire.'],
#  'embeddings': array([[-0.01585388, -0.02346802,  0.0385437 , ...,  0.00078487,
#          0.00345993,  0.00486374],
#        [ 0.00629807,  0.01608276,  0.02990723, ...,  0.01649475,
#          0.02906799,  0.01644897],
#        [-0.01037598, -0.02363586,  0.0369873 , ..., -0.0322876 ,
#          0.0329895 , -0.02191162],
#        ...,
#        [-0.01660156, -0.01385498, -0.00346947, ..., -0.02410889,
#          0.01020813, -0.03430176],
#        [ 0.02577209,  0.03240967,  0.07305908, ..., -0.00129986,
#          0.04959106, -0.04577637],
#        [-0.01139832,  0.00492859,  0.00013804, ..., -0.00764084,
#          0.03112793, -0.04794312]], shape=(82, 1536)),
#  'ids': ['chunk_0',
#          'chunk_1',
#          'chunk_2',
#          'chunk_3',
#          'chunk_4',
#          'chunk_5',
#          'chunk_6',
#          'chunk_7',
#          'chunk_8',
#          'chunk_9',
#          'chunk_10',
#          'chunk_11',
#          'chunk_12',
#          'chunk_13',
#          'chunk_14',
#          'chunk_15',
#          'chunk_16',
#          'chunk_17',
#          'chunk_18',
#          'chunk_19',
#          'chunk_20',
#          'chunk_21',
#          'chunk_22',
#          'chunk_23',
#          'chunk_24',
#          'chunk_25',
#          'chunk_26',
#          'chunk_27',
#          'chunk_28',
#          'chunk_29',
#          'chunk_30',
#          'chunk_31',
#          'chunk_32',
#          'chunk_33',
#          'chunk_34',
#          'chunk_35',
#          'chunk_36',
#          'chunk_37',
#          'chunk_38',
#          'chunk_39',
#          'chunk_40',
#          'chunk_41',
#          'chunk_42',
#          'chunk_43',
#          'chunk_44',
#          'chunk_45',
#          'chunk_46',
#          'chunk_47',
#          'chunk_48',
#          'chunk_49',
#          'chunk_50',
#          'chunk_51',
#          'chunk_52',
#          'chunk_53',
#          'chunk_54',
#          'chunk_55',
#          'chunk_56',
#          'chunk_57',
#          'chunk_58',
#          'chunk_59',
#          'chunk_60',
#          'chunk_61',
#          'chunk_62',
#          'chunk_63',
#          'chunk_64',
#          'chunk_65',
#          'chunk_66',
#          'chunk_67',
#          'chunk_68',
#          'chunk_69',
#          'chunk_70',
#          'chunk_71',
#          'chunk_72',
#          'chunk_73',
#          'chunk_74',
#          'chunk_75',
#          'chunk_76',
#          'chunk_77',
#          'chunk_78',
#          'chunk_79',
#          'chunk_80',
#          'chunk_81'],
#  'included': ['documents', 'embeddings'],
#  'metadatas': None,
#  'uris': None}

# %%
#Tesst retrieval

#Generate embedding for a test query
test_query = "peach"

#Embed the query using the same model we used for the chunks to ensure compatibility
#Tip: you will need to convert the query into a list before passing it in
#...
response = client.embeddings.create(
    model="text-embedding-3-small",
    input=[test_query]
)

query_embedding = response.data[0].embedding

#Search ChromaDB
#Tip: use collection.query()
#Tip: you will need to convert the query embedding into a list before passing it in
#...
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=3
)

#Verify retrieval works - print which chunks were retrieved and their content
#pprint(results)
print(f"Query: {test_query}")
print("Retrieved Chunks:")
#for chunk, metadata in ...
for a, b in zip(results["documents"][0], results["metadatas"][0]):
    print(f"Chunk {b['chunk_index']}:\n{a}\n")
# Out:
# Query: peach
# Retrieved Chunks:
# Chunk 73:
# ng highshool abroad
# - Andrea doesn't like cooking
# - Andrea loves peaches, she likes them by
#
# Chunk 60:
# Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo
#
# Chunk 59:
# Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress,

# %% [markdown]
# ### Step 3: Prepare the list of tools for the LLM

# %%
tools = []

# %% [markdown]
# ### Step 3a: Add tool-calling functionality (Pushover)

# %%
PUSHOVER_USER = os.getenv("PUSHOVER_USER")
PUSHOVER_TOKEN = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

#Create send_notification function
import requests

def send_notification(message: str):
    payload = {"user": PUSHOVER_USER, "token": PUSHOVER_TOKEN, "message": message}
    requests.post(pushover_url, data=payload)

#Describe Pushover as an LLM tool
send_notification_function = {
    "name": "send_notification",
    "description": "Sends a push notification to the real-world of you via Pushover on mobile. Use this if the user needs to alert the real-world version of you.",
    "parameters": {
        "type": "object",
        "properties": {
            "message": {
                "type": "string",
                "description": "The notification message to send to the user's device."
            }
        },
        "required": ["message"]
    }
}

#Add Pushover to the list of tools for the LLM
tools.append({"type": "function", "function": send_notification_function})

# %% [markdown]
# ### Step 3b: Add Dice-Rolling functionality

# %%
import random

#Simulates rolling a single six-sided die
def dice_roll():
    result = random.randint(1,6)
    return result

#Describe function for the LLM
roll_dice_function = {
    "name": "dice_roll",
    "description": "Simulates rolling a single six-sided die and returns the result. Use this when the user wants to roll a die for games, decisions, or random number generation.",
    "parameters": {
        "type": "object",
        "properties": {},
        "required": []
    }
}

#Add function to lit of tools of LLM
tools.append({"type": "function", "function": roll_dice_function})

# %% [markdown]
# ### Step 4: Function to handle LLM Tool calls

# %%
def handle_tool_call(tool_calls):
    tool_results = []

    for tool_call in tool_calls:
        function_name = tool_call.function.name
        args = json.loads(tool_call.function.arguments)
        #print(f"Calling function {function_name}") #For future debugging!

        #Route to the appropriate function based on function_name
        if function_name == "send_notification":
            send_notification(args["message"])
            content = f"Notification sent: {args['message']}"
        elif function_name == "dice_roll":
            content = f"Rolled: {dice_roll()}"
        #elif function_name == "insert_function_name_3":
            # content = insert_function_name3(args["message"])
        #....
        else:
            content = f"Unknown function: {function_name}"

        tool_call_result = {
            "role": "tool",
            "content": content,
            "tool_call_id": tool_call.id,
        }

        tool_results.append(tool_call_result)
    
    return tool_results

# %% [markdown]
# ### Step 5: Function to Process the Conversation Turn

# %%
system_message = """You are a digital twin of Andrea Gosset Soto. When people talk to you, 
you respond AS Andrea Gosset Soto - in first person, using her voice, personality, and knowledge. 
Start your very first message as: "Hi there! I'm Andrea" and go on with your regular message.

Important: d not make things up. If you don't know an answer, say you don't know.
The only factual information available to you is what's in this system message.
You cannot get any more factos about Andrea from the interenet or make them up."""

# %%
def response_ai(message, history):
    #RAG
    #Embed the query using the same model we used for the chunks to ensure compatibility
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=[message]
    )

    query_embedding = response.data[0].embedding

    #Search ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=3
    )

    #Stich retrieve chunks together to create the context for the response
    context = "\n---\n".join(results["documents"][0])
    print("Context this turn: \n", context)

    #Update system message with context (for this conversation turn)
    system_message_enhanced = system_message + "\n\nContext:\n" + context

    print(f"User message:\n{message}\n")
    print("Context this turn:\n", context)

    messages = [{"role": "system", "content": system_message_enhanced}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages,
        tools=tools
    )

    message = response.choices[0].message
    reply = response.choices[0].message.content

    while message.tool_calls:
        from pprint import pprint
        pprint(message.tool_calls)
        tools_result = handle_tool_call(message.tool_calls)
        messages.append(message)
        messages.extend(tools_result)
        response = client.chat.completions.create(
            model="gpt-4.1-mini",
            messages=messages,
            tools=tools
        )
        message = response.choices[0].message

        #Note: maybe consider adding protection from infinite consecutive tool calling
        
    return(message.content)

# %% [markdown]
# ### Step 6: Launch Gradio

# %%
gr.ChatInterface(fn=response_ai).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Context this turn:
#  nking as a mentor.
#
# Communication style:Friendly and accessible, thinking as a mentor.
# ---
# alongside the client Realogy using Angular 7, NgRx,
# ---
# e,
# Scrum, Kanban.
#
# Languages:
# English (fluent), Spanish (native), French (proficient).
# User message:
# hi there, who are you?
#
# Context this turn:
#  nking as a mentor.
#
# Communication style:Friendly and accessible, thinking as a mentor.
# ---
# alongside the client Realogy using Angular 7, NgRx,
# ---
# e,
# Scrum, Kanban.
#
# Languages:
# English (fluent), Spanish (native), French (proficient).
# Context this turn:
#  s, she likes them by themselves, on cakes, on jello,    with cinamon, etc.
# ---
# ng highshool abroad
# - Andrea doesn't like cooking
# - Andrea loves peaches, she likes them by
# ---
# Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo
# User message:
# what do you think about fruits?
#
# Context this turn:
#  s, she likes them by themselves, on cakes, on jello,    with cinamon, etc.
# ---
# ng highshool abroad
# - Andrea doesn't like cooking
# - Andrea loves peaches, she likes them by
# ---
# Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo
