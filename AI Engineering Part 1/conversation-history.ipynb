# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])


client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"system", "content": "You are a helfpul assistant."},
        {"role":"user", "content": "Next week I'm travelling to Spain."}
    ]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That’s exciting! Do you need any help with planning your trip, like places to visit, transportation tips, or packing suggestions?

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"system", "content": "You are a helfpul assistant."},
        {"role":"user", "content": "Where am I travelling to next week?"}
    ]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# I’m not able to access your personal information. Could you please tell me where you are travelling to next week? I’d be happy to help with information or tips about your destination!

# %% [markdown]
# ### In theory... (doing it manually for illustration)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Next week I'm travelling to Spain."},
    {"role": "assistant", "content": "That’s exciting! Do you need any help with planning your trip, like places to visit, transportation tips, or packing suggestions?"},
    {"role": "user", "content": "Where am I travelling to next week?"},
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# You are travelling to Spain next week.

# %% [markdown]
# ### Now: Not manually

# %%
messages = [
    {"role":"system", "content": "You are a helfpul assistant."},
    {"role":"user", "content": "Next week I'm travelling to Spain."}
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role":"assistant", "content":reply})


#display(Markdown(reply))
print(messages)
# Out:
# [{'role': 'system', 'content': 'You are a helfpul assistant.'}, {'role': 'user', 'content': "Next week I'm travelling to Spain."}, {'role': 'assistant', 'content': 'That sounds exciting! Do you need any tips or information for your trip to Spain? For example, recommendations on places to visit, local cuisine, language tips, or travel advice?'}]

# %%
from pprint import pprint
pprint(messages)
# Out:
# [{'content': 'You are a helfpul assistant.', 'role': 'system'},
#  {'content': "Next week I'm travelling to Spain.", 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information for '
#              'your trip to Spain? For example, recommendations on places to '
#              'visit, local cuisine, language tips, or travel advice?',
#   'role': 'assistant'}]

# %%
messages.append({"role": "user", "content": "Where am I travelling to next week?"})
pprint(messages)
# Out:
# [{'content': 'You are a helfpul assistant.', 'role': 'system'},
#  {'content': "Next week I'm travelling to Spain.", 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any help with your trip to '
#              'Spain? For example, recommendations on places to visit, things '
#              'to do, travel tips, or packing advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling to next week?', 'role': 'user'}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role":"assistant", "content": reply})
pprint(messages)
# Out:
# [{'content': 'You are a helfpul assistant.', 'role': 'system'},
#  {'content': "Next week I'm travelling to Spain.", 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any help with your trip to '
#              'Spain? For example, recommendations on places to visit, things '
#              'to do, travel tips, or packing advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Spain next week. Safe '
#              'travels! If you need any assistance with your trip, feel free to '
#              'ask.',
#   'role': 'assistant'}]

# %% [markdown]
# ### TODO: What's the capital?

# %%
messages.append({"role": "user", "content": "What is the capital?"})
pprint(messages)
# Out:
# [{'content': 'You are a helfpul assistant.', 'role': 'system'},
#  {'content': "Next week I'm travelling to Spain.", 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any help with your trip to '
#              'Spain? For example, recommendations on places to visit, things '
#              'to do, travel tips, or packing advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Spain next week. Safe '
#              'travels! If you need any assistance with your trip, feel free to '
#              'ask.',
#   'role': 'assistant'},
#  {'content': 'What is the capital?', 'role': 'user'}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"user": "assistant", "content": reply})
pprint(messages)
# Out:
# [{'content': 'You are a helfpul assistant.', 'role': 'system'},
#  {'content': "Next week I'm travelling to Spain.", 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any help with your trip to '
#              'Spain? For example, recommendations on places to visit, things '
#              'to do, travel tips, or packing advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling to next week?', 'role': 'user'},
#  {'content': 'You mentioned that you are traveling to Spain next week. Safe '
#              'travels! If you need any assistance with your trip, feel free to '
#              'ask.',
#   'role': 'assistant'},
#  {'content': 'What is the capital?', 'role': 'user'},
#  {'content': 'The capital of Spain is Madrid. It’s a vibrant city known for '
#              'its rich history, art museums, and lively culture. If you’re '
#              'planning to visit, there’s plenty to see and do!',
#   'user': 'assistant'}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"system", "content": "You are a helfpul assistant."},
        {"role":"user", "content": "What is an affordable openai current model that is good for searching?"}
    ]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# An affordable OpenAI model that is well-suited for searching tasks (such as semantic search, information retrieval, or document similarity) is one of the **embedding models** like:
#
# - **`text-embedding-ada-002`**
#
# This model provides high-quality embeddings at a relatively low cost and is frequently recommended for building search applications. You can generate vector embeddings of your documents and queries, then perform similarity searches using vector distance metrics.
#
# **Key points:**
#
# - **Cost-effective:** `text-embedding-ada-002` is among the cheapest embedding models.
# - **High performance:** It provides state-of-the-art embedding quality for semantic search.
# - **Versatile:** Works well for many languages and domains.
#
# If you want a model for generating natural language answers relevant to search queries, you might use a smaller GPT-4 or GPT-3.5 variant, but those are generally more expensive per request.
#
# **Summary:**
#
# - For indexing and similarity search: use **`text-embedding-ada-002`**.
# - For generating natural language answers or summaries: consider GPT-3.5 (`gpt-3.5-turbo`) which is relatively affordable compared to GPT-4.
#
# If cost is the main concern and your task is pure search, go with embeddings like `text-embedding-ada-002`.
