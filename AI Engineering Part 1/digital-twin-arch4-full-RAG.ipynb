# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
from pprint import pprint
import gradio as gr
import json
import re
import uuid
import chromadb
import random
import requests

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")

client = OpenAI()

# %% [markdown]
# ### Step 2: RAG Preparation

# %%
document_overview = """
Andrea is an experienced Front End Engineer. She's based in Atlanta, Georgia. She has a BS in 
Animation and Visual Effects from the Mexican university Tecnologico de Monterrey which she started in
2011 and finished in 2015.

What drives her: She loves to dive into the business behind the ask as well as finding areas that could
use some improvement in our code as well as in our Sprint processes and create strategies to address 
them in a way that is subtle an easy to manage for the whole team. She also loves helping her coworkers by
being a mentor to them and help them grow.

Her approach: Always thinking two steps ahead and thinking as a mentor.

Communication style: Friendly and accessible, thinking as a mentor.

Additional info:
- Andrea is not currently working in anything related to Animation and Digital Arts. She graduated on 2015
    and 3 months after that she took her first job as a Front End Developer and never looked back!
- In 2008 Andrea was studying highshool abroad
- Andrea doesn't like cooking
- Andrea loves peaches, she likes them by themselves, on cakes, on jello,\
    with cinamon, etc.
- Andrea has loved singing since she was a kid, previously she only did it\
    in the shower but as she grew older she started doing it while driving and almost everywhere she\
    could.. Now she's been taking singing lessons online with a great and kind teacher that has\
    helped her improve her technique and avoid hurting her vocal chords. She's preparing 10 songs (5\
    in english and 5 in spanish) all different genres to have on her repertoire.
"""

# %%
document_education = """
Disclamer: Andrea is not currently working in anything related to Animation and Digital Arts. 
She graduated on 2015 and 3 months after that she took her first job as a Front End Developer 
and never looked back!

College: Tecnológico de Monterrey
B. A. in Animation and Digital Arts, Animation and Digital Arts
From 2011 – 2015
Grade: 9.1 of 10

The Bachelor on Animation and Digital Arts or LAD is a comprehensive program designed to 
merge technology, narrative storytelling, and visual arts.Ranked as the #1 animation program 
in Mexico and #13 internationally by the Animation Career Review, this highly collaborative 
degree prepares students to produce content for the entertainment, advertising, and interactive 
media industries.

Core Pillars of the Curriculum
The career is structured around three foundational areas:Art & Design: Mastering aesthetics, 
character design, anatomy, digital drawing, and sculpture.Technology & Innovation: Utilizing 
industry-standard software, real-time engines, and emerging tools like AI, Virtual Reality (VR), 
and Augmented Reality (AR).Audiovisual Production & Narrative: Crafting compelling stories through 
storyboarding, cinematography, directing, and sound design.

Areas of Specialization (Concentrations)
Rather than focusing solely on one style, Tec de Monterrey offers sixteen distinct disciplinary 
concentrations to let students customize their career paths. Students can specialize in fields such 
as:
- Animation Styles: 2D Animation, 3D Character Animation, and Stop Motion.
- Gaming & Interactivity: Video Game Design, Immersive Environments, and User Experience/Interfaces (UX/UI).
- Post-Production: Sound Design, Visual Effects (VFX), Digital Modeling, and Lighting.
- Film & Business: Film Production and Direction, Creative Writing, and Entrepreneurship in the Creative Industries.

Career Opportunities & Alumni Success
Graduates are trained not just to be technicians, but to act as creative directors and technical 
directors. They find placement in:Global Animation & VFX Studios: Alumni have worked at [Sony Pictures 
Imageworks, Moving Picture Company (MPC), Netflix, and Cinesite].Major Hollywood Productions: Grads 
have contributed to films like Spider-Man: Across the Spider-Verse, Guardians of the Galaxy Vol. 3, 
Dune, and Avatar.Diverse Sectors: Video game development, commercial advertising, UI/UX design, and 
architectural visualization.
"""

# %%
document_professional_experience = """
She's been a Front End Engineer since 2016 creating web applications and managing 
CMS across various industries. Proven team leader with a strong commitment to understanding business 
aspects for innovative solutions, showcasing skills in mentorship, continuous learning, and optimizing 
user experience through modern technologies.
2015: Intern at MetaCube as a 3D Digital Modeller for the Dia de Muertos movie
2016-2018: Front End Engineer at Base22
2018-2022: Senior Front End Engineer at Globant
    - Led a consulting team to develop two intranets alongside the client Realogy using Angular 7, NgRx, 
    Jasmine, and Apollo GraphQL, resulting in realtors benefiting from a centralized platform for 
    accessing their essential day-to-day tools.
    - Engineered an npm library with Node to seamlessly integrate a standardized theme across various 
    intranets and applications, improving consistency, efficiency, and fostering a more unified and 
    cohesive visual identity.
    - Collaborated with Stanley Black and Decker's team to enhance their Site Manager and Public API 
    intranets. Developed a comprehensive week-to-week action plan streamlining their development and 
    Scrum processes.
    - Mentored 3 peers at a time to facilitate their career advancement within their teams, providing 
    guidance and support.
    - Conducted thorough interviews with prospective candidates for seamless integration into the company.

2022-2023: Software Engineer at Twitter
    - Directed the front-end effort for the Semantic Core UI migration leveraging React.js, Typescript, 
    Javascript, and CSS enabling clients to efficiently gather insights for optimal ad promotion within 
    Twitter's internal platform.
    - Mentored and spearheaded a 5-person division within the TwST (Twitter Security Team) department, 
    fostering professional growth, team cohesion, and cross-functional collaboration to achieve key 
    departmental objectives.
    - Authored the Technical Design Document for the Semantic Core UI migration to accommodate new 
    implementations, enhance code quality, and improve maintainability to ensure an organized and 
    well-architectured development.

2023-Present: Senior Front End Engineer at Rooms To Go
    Improved website performance, streamlined content updates, and collaborated with cross-functional 
    teams to implement key features. Additionally led the front-end team, optimizing Agile processes 
    to enhance efficiency and delivery.
    - Spearheaded front-end artificial intelligence (AI) projects, enhancing customer engagement and 
    contributing to a 30 percent boost in sales revenue.
    - Migrated the main E-commerce webpage from React.js and MUI to Next.js, TypeScript, and Tailwind, 
    implementing a more efficient server-side solution that resulted in a 45% performance improvement, 
    enhancing the user experience.
    - Developed, updated, and revamped React.js components, Strapi schemas, and the organization's npm 
    library to streamline E-Commerce content updates, ensuring timely refreshes that featured weekly 
    sales and drove increased revenue.
    - Collaborated with the Content, UX and Marketing teams to gather and comprehend new requirements, 
    translating them into actionable tickets while assuming leadership responsibilities for their 
    implementation within the front-end team.

Technical Skills:
Javascript (ES6+), React.js, Typescript, Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress, 
Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo GraphQL, REST APIs, n8n, 
Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node, Scala, Strapi, IBM WCM, Liferay DXP, Git, Agile, 
Scrum, Kanban.

Languages:
English (fluent), Spanish (native), French (proficient).
"""

# %%
def split_text_into_chunks(
    text: str,
    max_chunk_size: int = 500,
    overlap: int = 50,
) -> list[str]:
    chunks = []
    start = 0

    while start < len(text):
        max_end = min(start + max_chunk_size, len(text))

        if max_end == len(text):
            chunks.append(text[start:].strip())
            break

        halfway = start + max_chunk_size // 2
        section = text[halfway:max_end]

        # Boundaries in priority order
        boundaries = [
            section.rfind("\n\n"),
            section.rfind("\n"),
        ]

        sentence_matches = list(re.finditer(r"[.!?](?=\s|$)", section))
        boundaries.append(
            sentence_matches[-1].end() if sentence_matches else -1
        )

        boundaries.append(section.rfind(" "))

        # Use the first boundary type that exists.
        cut = next((b for b in boundaries if b != -1), None)

        end = halfway + cut if cut is not None else max_end

        # Include the boundary character(s) for sentence/newline cuts.
        if cut is not None:
            if text[end:end + 2] == "\n\n":
                end += 2
            elif text[end:end + 1] == "\n":
                end += 1
            elif end < len(text) and text[end] in ".!?":
                end += 1

        chunks.append(text[start:end].strip())

        start = end - overlap

    return chunks

# %%
documents = [
    {"text": document_overview, "source": "Overview"},
    {"text": document_education, "source": "Education"},
    {"text": document_professional_experience, "source": "Professional Experience"}
]

chunks = []
ids = []
metadatas = []

for doc in documents:
    #Prepare the lists
    chunks_ = split_text_into_chunks(doc["text"], max_chunk_size=300, overlap=30)
    ids_ = [str(uuid.uuid4()) for _ in range(len(chunks_))]
    metadatas_ = [{"source": doc["source"], "chunk_index": i} for i in range(len(chunks_))]

    #Add to main lists
    chunks.extend(chunks_)
    ids.extend(ids_)
    metadatas.extend(metadatas_)

print(f"Created {len(chunks)} chunks: \n")

for i, chunk in enumerate(chunks):
    #print(f"--- Chunk {i + 1} | {len(chunk)} chars ---")
    print(f"--- Chunk {i + 1} (ID: {ids[i]}, Source: {metadatas[i]['source']}, Index: {metadatas[i]['chunk_index']}, Length: {len(chunk)}):")
    print(chunk)
    print()
# Out:
# Created 36 chunks:
#
# --- Chunk 1 (ID: 84f53c7e-25b2-4fa8-9309-3b319518f4a6, Source: Overview, Index: 0, Length: 224):
# Andrea is an experienced Front End Engineer. She's based in Atlanta, Georgia. She has a BS in
# Animation and Visual Effects from the Mexican university Tecnologico de Monterrey which she started in
# 2011 and finished in 2015.
#
# --- Chunk 2 (ID: 322d6c38-91fb-4047-8e5b-937232948943, Source: Overview, Index: 1, Length: 234):
# n
# 2011 and finished in 2015.
#
# What drives her: She loves to dive into the business behind the ask as well as finding areas that could
# use some improvement in our code as well as in our Sprint processes and create strategies to address
#
# --- Chunk 3 (ID: 3af1c630-9105-41a0-903d-6aef763b52d7, Source: Overview, Index: 2, Length: 252):
# create strategies to address
# them in a way that is subtle an easy to manage for the whole team. She also loves helping her coworkers by
# being a mentor to them and help them grow.
#
# Her approach: Always thinking two steps ahead and thinking as a mentor.
#
# --- Chunk 4 (ID: f49a6070-bf55-4ed2-a0bd-c76e8db238c8, Source: Overview, Index: 3, Length: 222):
# ad and thinking as a mentor.
#
# Communication style: Friendly and accessible, thinking as a mentor.
#
# Additional info:
# - Andrea is not currently working in anything related to Animation and Digital Arts. She graduated on 2015
#
# --- Chunk 5 (ID: ca278015-a09e-4994-a9f3-766832d60501, Source: Overview, Index: 4, Length: 205):
# l Arts. She graduated on 2015
#     and 3 months after that she took her first job as a Front End Developer and never looked back!
# - In 2008 Andrea was studying highshool abroad
# - Andrea doesn't like cooking
#
# --- Chunk 6 (ID: e4052947-2f07-4fb3-9124-25f6688739ae, Source: Overview, Index: 5, Length: 296):
# - Andrea doesn't like cooking
# - Andrea loves peaches, she likes them by themselves, on cakes, on jello,    with cinamon, etc.
# - Andrea has loved singing since she was a kid, previously she only did it    in the shower but as she grew older she started doing it while driving and almost everywhere
#
# --- Chunk 7 (ID: 7657db7e-86cd-4476-9fc0-76a57b28ea08, Source: Overview, Index: 6, Length: 200):
# driving and almost everywhere she    could.. Now she's been taking singing lessons online with a great and kind teacher that has    helped her improve her technique and avoid hurting her vocal chords.
#
# --- Chunk 8 (ID: 1c269cae-3230-443c-86ad-6eb3dc14b2e6, Source: Overview, Index: 7, Length: 138):
# void hurting her vocal chords. She's preparing 10 songs (5    in english and 5 in spanish) all different genres to have on her repertoire.
#
# --- Chunk 9 (ID: ac332090-aa50-4ddc-8e10-aeebc2ca7e15, Source: Education, Index: 0, Length: 212):
# Disclamer: Andrea is not currently working in anything related to Animation and Digital Arts.
# She graduated on 2015 and 3 months after that she took her first job as a Front End Developer
# and never looked back!
#
# --- Chunk 10 (ID: eb7e0126-4c6e-42f6-8db6-0d62efc05031, Source: Education, Index: 1, Length: 161):
# oper
# and never looked back!
#
# College: Tecnológico de Monterrey
# B. A. in Animation and Digital Arts, Animation and Digital Arts
# From 2011 – 2015
# Grade: 9.1 of 10
#
# --- Chunk 11 (ID: bb3268c8-2cf5-4742-a6cb-bf7d3ba4715e, Source: Education, Index: 2, Length: 212):
# 2011 – 2015
# Grade: 9.1 of 10
#
# The Bachelor on Animation and Digital Arts or LAD is a comprehensive program designed to
# merge technology, narrative storytelling, and visual arts.Ranked as the #1 animation program
#
# --- Chunk 12 (ID: 9f7ddcf5-16b6-46dc-b224-16a93282a2a8, Source: Education, Index: 3, Length: 236):
# as the #1 animation program
# in Mexico and #13 internationally by the Animation Career Review, this highly collaborative
# degree prepares students to produce content for the entertainment, advertising, and interactive
# media industries.
#
# --- Chunk 13 (ID: a5395e9a-4574-4198-a326-a8f35c22b581, Source: Education, Index: 4, Length: 247):
# teractive
# media industries.
#
# Core Pillars of the Curriculum
# The career is structured around three foundational areas:Art & Design: Mastering aesthetics,
# character design, anatomy, digital drawing, and sculpture.Technology & Innovation: Utilizing
#
# --- Chunk 14 (ID: 7f8cb317-ae30-487c-b1ef-8f5fe39daad3, Source: Education, Index: 5, Length: 287):
# logy & Innovation: Utilizing
# industry-standard software, real-time engines, and emerging tools like AI, Virtual Reality (VR),
# and Augmented Reality (AR).Audiovisual Production & Narrative: Crafting compelling stories through
# storyboarding, cinematography, directing, and sound design.
#
# --- Chunk 15 (ID: 83cbcd3a-85ba-4286-8136-c246de0304a8, Source: Education, Index: 6, Length: 272):
# directing, and sound design.
#
# Areas of Specialization (Concentrations)
# Rather than focusing solely on one style, Tec de Monterrey offers sixteen distinct disciplinary
# concentrations to let students customize their career paths. Students can specialize in fields such
# as:
#
# --- Chunk 16 (ID: e341eb53-dd14-4578-9ae7-2a6f81538f1d, Source: Education, Index: 7, Length: 213):
# pecialize in fields such
# as:
# - Animation Styles: 2D Animation, 3D Character Animation, and Stop Motion.
# - Gaming & Interactivity: Video Game Design, Immersive Environments, and User Experience/Interfaces (UX/UI).
#
# --- Chunk 17 (ID: 24843473-765a-4f8c-a339-685d368af60c, Source: Education, Index: 8, Length: 233):
# xperience/Interfaces (UX/UI).
# - Post-Production: Sound Design, Visual Effects (VFX), Digital Modeling, and Lighting.
# - Film & Business: Film Production and Direction, Creative Writing, and Entrepreneurship in the Creative Industries.
#
# --- Chunk 18 (ID: 9fd9a05b-833e-45b3-83d6-1a172a1a2074, Source: Education, Index: 9, Length: 267):
# in the Creative Industries.
#
# Career Opportunities & Alumni Success
# Graduates are trained not just to be technicians, but to act as creative directors and technical
# directors. They find placement in:Global Animation & VFX Studios: Alumni have worked at [Sony Pictures
#
# --- Chunk 19 (ID: b0b5e801-efdc-40fb-a367-cad8b3f6a508, Source: Education, Index: 10, Length: 230):
# ave worked at [Sony Pictures
# Imageworks, Moving Picture Company (MPC), Netflix, and Cinesite].Major Hollywood Productions: Grads
# have contributed to films like Spider-Man: Across the Spider-Verse, Guardians of the Galaxy Vol. 3,
#
# --- Chunk 20 (ID: 272e0ca6-bf44-4245-9b12-e13d066b319e, Source: Education, Index: 11, Length: 159):
# rdians of the Galaxy Vol. 3,
# Dune, and Avatar.Diverse Sectors: Video game development, commercial advertising, UI/UX design, and
# architectural visualization.
#
# --- Chunk 21 (ID: fb1a52bf-a898-4f78-a1ed-23f574c86b46, Source: Professional Experience, Index: 0, Length: 287):
# She's been a Front End Engineer since 2016 creating web applications and managing
# CMS across various industries. Proven team leader with a strong commitment to understanding business
# aspects for innovative solutions, showcasing skills in mentorship, continuous learning, and optimizing
#
# --- Chunk 22 (ID: c627c741-18fe-497f-8bbd-eaf94c56b5a3, Source: Professional Experience, Index: 1, Length: 241):
# ous learning, and optimizing
# user experience through modern technologies.
# 2015: Intern at MetaCube as a 3D Digital Modeller for the Dia de Muertos movie
# 2016-2018: Front End Engineer at Base22
# 2018-2022: Senior Front End Engineer at Globant
#
# --- Chunk 23 (ID: 5340e6b5-b1f9-4fb5-955d-5fd0f3a3f086, Source: Professional Experience, Index: 2, Length: 282):
# Front End Engineer at Globant
#     - Led a consulting team to develop two intranets alongside the client Realogy using Angular 7, NgRx,
#     Jasmine, and Apollo GraphQL, resulting in realtors benefiting from a centralized platform for
#     accessing their essential day-to-day tools.
#
# --- Chunk 24 (ID: 067dfbf5-5830-42c5-82ae-0195d7422654, Source: Professional Experience, Index: 3, Length: 263):
# r essential day-to-day tools.
#     - Engineered an npm library with Node to seamlessly integrate a standardized theme across various
#     intranets and applications, improving consistency, efficiency, and fostering a more unified and
#     cohesive visual identity.
#
# --- Chunk 25 (ID: fc707547-f18b-4467-ac86-3416d3c86b49, Source: Professional Experience, Index: 4, Length: 250):
# cohesive visual identity.
#     - Collaborated with Stanley Black and Decker's team to enhance their Site Manager and Public API
#     intranets. Developed a comprehensive week-to-week action plan streamlining their development and
#     Scrum processes.
#
# --- Chunk 26 (ID: 590e2089-767b-4d37-87ed-35c86cb1b37c, Source: Professional Experience, Index: 5, Length: 265):
# ent and
#     Scrum processes.
#     - Mentored 3 peers at a time to facilitate their career advancement within their teams, providing
#     guidance and support.
#     - Conducted thorough interviews with prospective candidates for seamless integration into the company.
#
# --- Chunk 27 (ID: e8facb9d-04fd-4d57-8931-f1fb13a0719b, Source: Professional Experience, Index: 6, Length: 278):
# ntegration into the company.
#
# 2022-2023: Software Engineer at Twitter
#     - Directed the front-end effort for the Semantic Core UI migration leveraging React.js, Typescript,
#     Javascript, and CSS enabling clients to efficiently gather insights for optimal ad promotion within
#
# --- Chunk 28 (ID: 25bb2d2e-3bf6-4a1f-95f1-5d185ae67dcd, Source: Professional Experience, Index: 7, Length: 295):
# optimal ad promotion within
#     Twitter's internal platform.
#     - Mentored and spearheaded a 5-person division within the TwST (Twitter Security Team) department,
#     fostering professional growth, team cohesion, and cross-functional collaboration to achieve key
#     departmental objectives.
#
# --- Chunk 29 (ID: 065325ec-e659-456e-a938-90ba2a1d9dc8, Source: Professional Experience, Index: 8, Length: 259):
# departmental objectives.
#     - Authored the Technical Design Document for the Semantic Core UI migration to accommodate new
#     implementations, enhance code quality, and improve maintainability to ensure an organized and
#     well-architectured development.
#
# --- Chunk 30 (ID: 96b0ad86-4efc-402d-8f0a-e30284909242, Source: Professional Experience, Index: 9, Length: 288):
# l-architectured development.
#
# 2023-Present: Senior Front End Engineer at Rooms To Go
#     Improved website performance, streamlined content updates, and collaborated with cross-functional
#     teams to implement key features. Additionally led the front-end team, optimizing Agile processes
#
# --- Chunk 31 (ID: c0fed5d2-2453-4073-ac03-575780a4dbd4, Source: Professional Experience, Index: 10, Length: 228):
# , optimizing Agile processes
#     to enhance efficiency and delivery.
#     - Spearheaded front-end artificial intelligence (AI) projects, enhancing customer engagement and
#     contributing to a 30 percent boost in sales revenue.
#
# --- Chunk 32 (ID: 18a739f4-326b-48fb-9c01-e6e53778ad19, Source: Professional Experience, Index: 11, Length: 272):
# rcent boost in sales revenue.
#     - Migrated the main E-commerce webpage from React.js and MUI to Next.js, TypeScript, and Tailwind,
#     implementing a more efficient server-side solution that resulted in a 45% performance improvement,
#     enhancing the user experience.
#
# --- Chunk 33 (ID: 7ec9f563-6971-437e-a352-c3053cae4408, Source: Professional Experience, Index: 12, Length: 274):
# nhancing the user experience.
#     - Developed, updated, and revamped React.js components, Strapi schemas, and the organization's npm
#     library to streamline E-Commerce content updates, ensuring timely refreshes that featured weekly
#     sales and drove increased revenue.
#
# --- Chunk 34 (ID: 6fd1650e-b95f-47c9-860e-a4b56aab7dc2, Source: Professional Experience, Index: 13, Length: 277):
# and drove increased revenue.
#     - Collaborated with the Content, UX and Marketing teams to gather and comprehend new requirements,
#     translating them into actionable tickets while assuming leadership responsibilities for their
#     implementation within the front-end team.
#
# --- Chunk 35 (ID: 8b472981-ab17-45c8-9064-7d984833a61f, Source: Professional Experience, Index: 14, Length: 244):
# n within the front-end team.
#
# Technical Skills:
# Javascript (ES6+), React.js, Typescript, Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo GraphQL, REST APIs, n8n,
#
# --- Chunk 36 (ID: 3a656e9d-e4eb-4956-a636-7f1421b3a779, Source: Professional Experience, Index: 15, Length: 215):
# llo GraphQL, REST APIs, n8n,
# Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node, Scala, Strapi, IBM WCM, Liferay DXP, Git, Agile,
# Scrum, Kanban.
#
# Languages:
# English (fluent), Spanish (native), French (proficient).

# %%
#Generate embeddings for all chunks
response = client.embeddings.create(
    model ="text-embedding-3-small",
    input = chunks
)
embeddings = [item.embedding for item in response.data]

#Verify embeddings
print(f"Generated {len(embeddings)} embeddings")
print(f"Each embedding has {len(embeddings[0])} dimensions")
# Out:
# Generated 36 embeddings
# Each embedding has 1536 dimensions

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

reduced = TSNE(n_components=2, random_state=42, perplexity=min(30, len(embeddings)-1)).fit_transform(np.array(embeddings))
labels = KMeans(n_clusters=2, random_state=42).fit_predict(np.array(embeddings))

plt.figure(figsize=(8,6))
scatter = plt.scatter(reduced[:,0], reduced[:, 1], c=labels, cmap="bwr", alpha=0.7, s=50)

for i, (x,y) in enumerate(reduced):
    plt.annotate(str(i), (x,y), fontsize=7, alpha=0.6)

plt.legend(*scatter.legend_elements(), title="Cluster")
plt.title("Chunk Embeddings (t-SNE, 2 Clusters)")
plt.tight_layout()
plt.show()


from sklearn.cluster import KMeans

n_clusters = 4

labels = KMeans(
    n_clusters=n_clusters,
    random_state=42
).fit_predict(embeddings)

for cluster in range(n_clusters):
    cluster_text = "\n\n".join(
        chunks[i] for i, label in enumerate(labels) if label == cluster
    )

    response = client.responses.create(
        model="gpt-4.1-mini",
        input=f"""Describe the main topic represented by this cluster
in 1-2 sentences:

{cluster_text}"""
    )

    print(f"Cluster {cluster}: {response.output_text}\n")
# Out:
# Cluster 0: The cluster highlights the Bachelor program in Animation and Digital Arts at Tec de Monterrey, emphasizing its integration of technology, storytelling, and visual arts. It covers curriculum pillars, specialization options, industry-relevant skills, and successful alumni placements in top global animation, film, gaming, and media companies.
#
# Cluster 1: This cluster primarily focuses on the professional journey and expertise of a senior front-end engineer, highlighting her technical skills, leadership roles, mentorship approach, and contributions to web application development and process optimization across various companies. It emphasizes her commitment to understanding business needs, improving team workflows, and fostering career growth within engineering teams.
#
# Cluster 2: This cluster centers around Andrea, a Front End Engineer based in Atlanta, Georgia, who transitioned from a degree in Animation and Digital Arts to a successful career in front-end development starting shortly after graduation. It also highlights her personal interests, including her love for peaches and singing, as well as her journey improving her vocal skills through online lessons.
#
# Cluster 3: This cluster primarily focuses on front-end development initiatives involving the migration and optimization of web applications using modern frameworks and technologies, UI/UX improvements, and the creation of reusable tools and libraries to enhance consistency and performance. It also highlights leadership in Agile project management and cross-team collaboration aimed at boosting customer engagement and driving sales revenue.

# %%
#Initialize ChromaDB and Store Vectors

#initialize ChromaDB client (persistent storage)
chroma_client = chromadb.PersistentClient(path="./chroma_db_twin")

#initialize ChromaDB client (in-memory   storage)
#chroma_client = chromadb.Client()

collection = chroma_client.get_or_create_collection(name="digital_twin")

#Emtoy the collection before adding new data (for testint purposes in regular projects you don't need this functionality)
if collection.get()["ids"]:
    collection.delete(collection.get()["ids"])

pprint(collection.get())
# Out:
# {'data': None,
#  'documents': [],
#  'embeddings': None,
#  'ids': [],
#  'included': ['metadatas', 'documents'],
#  'metadatas': [],
#  'uris': None}

# %%
#Adding data to ChromaDB
collection.add(
    ids=ids,
    embeddings=embeddings,
    documents=chunks,
    metadatas=metadatas
)

pprint(collection.get(include=["documents", "embeddings", "metadatas"]))
# Out:
# {'data': None,
#  'documents': ["Andrea is an experienced Front End Engineer. She's based in "
#                'Atlanta, Georgia. She has a BS in \n'
#                'Animation and Visual Effects from the Mexican university '
#                'Tecnologico de Monterrey which she started in\n'
#                '2011 and finished in 2015.',
#                'n\n'
#                '2011 and finished in 2015.\n'
#                '\n'
#                'What drives her: She loves to dive into the business behind '
#                'the ask as well as finding areas that could\n'
#                'use some improvement in our code as well as in our Sprint '
#                'processes and create strategies to address',
#                'create strategies to address \n'
#                'them in a way that is subtle an easy to manage for the whole '
#                'team. She also loves helping her coworkers by\n'
#                'being a mentor to them and help them grow.\n'
#                '\n'
#                'Her approach: Always thinking two steps ahead and thinking as '
#                'a mentor.',
#                'ad and thinking as a mentor.\n'
#                '\n'
#                'Communication style: Friendly and accessible, thinking as a '
#                'mentor.\n'
#                '\n'
#                'Additional info:\n'
#                '- Andrea is not currently working in anything related to '
#                'Animation and Digital Arts. She graduated on 2015',
#                'l Arts. She graduated on 2015\n'
#                '    and 3 months after that she took her first job as a Front '
#                'End Developer and never looked back!\n'
#                '- In 2008 Andrea was studying highshool abroad\n'
#                "- Andrea doesn't like cooking",
#                "- Andrea doesn't like cooking\n"
#                '- Andrea loves peaches, she likes them by themselves, on '
#                'cakes, on jello,    with cinamon, etc.\n'
#                '- Andrea has loved singing since she was a kid, previously she '
#                'only did it    in the shower but as she grew older she started '
#                'doing it while driving and almost everywhere',
#                "driving and almost everywhere she    could.. Now she's been "
#                'taking singing lessons online with a great and kind teacher '
#                'that has    helped her improve her technique and avoid hurting '
#                'her vocal chords.',
#                "void hurting her vocal chords. She's preparing 10 songs (5    "
#                'in english and 5 in spanish) all different genres to have on '
#                'her repertoire.',
#                'Disclamer: Andrea is not currently working in anything related '
#                'to Animation and Digital Arts. \n'
#                'She graduated on 2015 and 3 months after that she took her '
#                'first job as a Front End Developer \n'
#                'and never looked back!',
#                'oper \n'
#                'and never looked back!\n'
#                '\n'
#                'College: Tecnológico de Monterrey\n'
#                'B. A. in Animation and Digital Arts, Animation and Digital '
#                'Arts\n'
#                'From 2011 – 2015\n'
#                'Grade: 9.1 of 10',
#                '2011 – 2015\n'
#                'Grade: 9.1 of 10\n'
#                '\n'
#                'The Bachelor on Animation and Digital Arts or LAD is a '
#                'comprehensive program designed to \n'
#                'merge technology, narrative storytelling, and visual '
#                'arts.Ranked as the #1 animation program',
#                'as the #1 animation program \n'
#                'in Mexico and #13 internationally by the Animation Career '
#                'Review, this highly collaborative \n'
#                'degree prepares students to produce content for the '
#                'entertainment, advertising, and interactive \n'
#                'media industries.',
#                'teractive \n'
#                'media industries.\n'
#                '\n'
#                'Core Pillars of the Curriculum\n'
#                'The career is structured around three foundational areas:Art & '
#                'Design: Mastering aesthetics, \n'
#                'character design, anatomy, digital drawing, and '
#                'sculpture.Technology & Innovation: Utilizing',
#                'logy & Innovation: Utilizing \n'
#                'industry-standard software, real-time engines, and emerging '
#                'tools like AI, Virtual Reality (VR), \n'
#                'and Augmented Reality (AR).Audiovisual Production & Narrative: '
#                'Crafting compelling stories through \n'
#                'storyboarding, cinematography, directing, and sound design.',
#                'directing, and sound design.\n'
#                '\n'
#                'Areas of Specialization (Concentrations)\n'
#                'Rather than focusing solely on one style, Tec de Monterrey '
#                'offers sixteen distinct disciplinary \n'
#                'concentrations to let students customize their career paths. '
#                'Students can specialize in fields such \n'
#                'as:',
#                'pecialize in fields such \n'
#                'as:\n'
#                '- Animation Styles: 2D Animation, 3D Character Animation, and '
#                'Stop Motion.\n'
#                '- Gaming & Interactivity: Video Game Design, Immersive '
#                'Environments, and User Experience/Interfaces (UX/UI).',
#                'xperience/Interfaces (UX/UI).\n'
#                '- Post-Production: Sound Design, Visual Effects (VFX), Digital '
#                'Modeling, and Lighting.\n'
#                '- Film & Business: Film Production and Direction, Creative '
#                'Writing, and Entrepreneurship in the Creative Industries.',
#                'in the Creative Industries.\n'
#                '\n'
#                'Career Opportunities & Alumni Success\n'
#                'Graduates are trained not just to be technicians, but to act '
#                'as creative directors and technical \n'
#                'directors. They find placement in:Global Animation & VFX '
#                'Studios: Alumni have worked at [Sony Pictures',
#                'ave worked at [Sony Pictures \n'
#                'Imageworks, Moving Picture Company (MPC), Netflix, and '
#                'Cinesite].Major Hollywood Productions: Grads \n'
#                'have contributed to films like Spider-Man: Across the '
#                'Spider-Verse, Guardians of the Galaxy Vol. 3,',
#                'rdians of the Galaxy Vol. 3, \n'
#                'Dune, and Avatar.Diverse Sectors: Video game development, '
#                'commercial advertising, UI/UX design, and \n'
#                'architectural visualization.',
#                "She's been a Front End Engineer since 2016 creating web "
#                'applications and managing \n'
#                'CMS across various industries. Proven team leader with a '
#                'strong commitment to understanding business \n'
#                'aspects for innovative solutions, showcasing skills in '
#                'mentorship, continuous learning, and optimizing',
#                'ous learning, and optimizing \n'
#                'user experience through modern technologies.\n'
#                '2015: Intern at MetaCube as a 3D Digital Modeller for the Dia '
#                'de Muertos movie\n'
#                '2016-2018: Front End Engineer at Base22\n'
#                '2018-2022: Senior Front End Engineer at Globant',
#                'Front End Engineer at Globant\n'
#                '    - Led a consulting team to develop two intranets alongside '
#                'the client Realogy using Angular 7, NgRx, \n'
#                '    Jasmine, and Apollo GraphQL, resulting in realtors '
#                'benefiting from a centralized platform for \n'
#                '    accessing their essential day-to-day tools.',
#                'r essential day-to-day tools.\n'
#                '    - Engineered an npm library with Node to seamlessly '
#                'integrate a standardized theme across various \n'
#                '    intranets and applications, improving consistency, '
#                'efficiency, and fostering a more unified and \n'
#                '    cohesive visual identity.',
#                'cohesive visual identity.\n'
#                "    - Collaborated with Stanley Black and Decker's team to "
#                'enhance their Site Manager and Public API \n'
#                '    intranets. Developed a comprehensive week-to-week action '
#                'plan streamlining their development and \n'
#                '    Scrum processes.',
#                'ent and \n'
#                '    Scrum processes.\n'
#                '    - Mentored 3 peers at a time to facilitate their career '
#                'advancement within their teams, providing \n'
#                '    guidance and support.\n'
#                '    - Conducted thorough interviews with prospective '
#                'candidates for seamless integration into the company.',
#                'ntegration into the company.\n'
#                '\n'
#                '2022-2023: Software Engineer at Twitter\n'
#                '    - Directed the front-end effort for the Semantic Core UI '
#                'migration leveraging React.js, Typescript, \n'
#                '    Javascript, and CSS enabling clients to efficiently gather '
#                'insights for optimal ad promotion within',
#                'optimal ad promotion within \n'
#                "    Twitter's internal platform.\n"
#                '    - Mentored and spearheaded a 5-person division within the '
#                'TwST (Twitter Security Team) department, \n'
#                '    fostering professional growth, team cohesion, and '
#                'cross-functional collaboration to achieve key \n'
#                '    departmental objectives.',
#                'departmental objectives.\n'
#                '    - Authored the Technical Design Document for the Semantic '
#                'Core UI migration to accommodate new \n'
#                '    implementations, enhance code quality, and improve '
#                'maintainability to ensure an organized and \n'
#                '    well-architectured development.',
#                'l-architectured development.\n'
#                '\n'
#                '2023-Present: Senior Front End Engineer at Rooms To Go\n'
#                '    Improved website performance, streamlined content updates, '
#                'and collaborated with cross-functional \n'
#                '    teams to implement key features. Additionally led the '
#                'front-end team, optimizing Agile processes',
#                ', optimizing Agile processes \n'
#                '    to enhance efficiency and delivery.\n'
#                '    - Spearheaded front-end artificial intelligence (AI) '
#                'projects, enhancing customer engagement and \n'
#                '    contributing to a 30 percent boost in sales revenue.',
#                'rcent boost in sales revenue.\n'
#                '    - Migrated the main E-commerce webpage from React.js and '
#                'MUI to Next.js, TypeScript, and Tailwind, \n'
#                '    implementing a more efficient server-side solution that '
#                'resulted in a 45% performance improvement, \n'
#                '    enhancing the user experience.',
#                'nhancing the user experience.\n'
#                '    - Developed, updated, and revamped React.js components, '
#                "Strapi schemas, and the organization's npm \n"
#                '    library to streamline E-Commerce content updates, ensuring '
#                'timely refreshes that featured weekly \n'
#                '    sales and drove increased revenue.',
#                'and drove increased revenue.\n'
#                '    - Collaborated with the Content, UX and Marketing teams to '
#                'gather and comprehend new requirements, \n'
#                '    translating them into actionable tickets while assuming '
#                'leadership responsibilities for their \n'
#                '    implementation within the front-end team.',
#                'n within the front-end team.\n'
#                '\n'
#                'Technical Skills:\n'
#                'Javascript (ES6+), React.js, Typescript, Next.js, Angular 7, '
#                'Vue, jQuery, Jest, Jasmine, Cypress, \n'
#                'Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, '
#                'Tailwind, Apollo GraphQL, REST APIs, n8n,',
#                'llo GraphQL, REST APIs, n8n, \n'
#                'Claude, Cursor, Gemini, Webpack, Gulp, Grunt, Node, Scala, '
#                'Strapi, IBM WCM, Liferay DXP, Git, Agile, \n'
#                'Scrum, Kanban.\n'
#                '\n'
#                'Languages:\n'
#                'English (fluent), Spanish (native), French (proficient).'],
#  'embeddings': array([[-0.00654221, -0.01215363,  0.03543091, ...,  0.00010788,
#          0.00659561,  0.00367737],
#        [ 0.01916504,  0.03103638,  0.06988525, ..., -0.03042603,
#          0.01960754, -0.00485992],
#        [ 0.03114319, -0.01641846,  0.04147339, ..., -0.05874634,
#          0.00891876, -0.0074501 ],
#        ...,
#        [-0.0024662 , -0.02404785,  0.02047729, ...,  0.00059271,
#         -0.00809479, -0.01153564],
#        [-0.03588867,  0.01447296,  0.02450562, ...,  0.01583862,
#         -0.00046158,  0.01385498],
#        [-0.04394531,  0.04193115,  0.05480957, ..., -0.01396942,
#          0.015625  , -0.00694275]], shape=(36, 1536)),
#  'ids': ['f3915c03-8c82-4c27-a6f3-4604994b327e',
#          'cf9af671-07ea-4b7e-9247-3598d08baf8e',
#          'cd3d9af2-ae70-4489-8e2f-ad283baa9b2f',
#          '24dd5281-da7b-4c8c-b91e-b5a207c833b6',
#          'edcbb00a-6b94-4049-8816-70eb24a1db6a',
#          'a9b99829-2848-4d7b-8efc-4f1ea71ec9c0',
#          'df936a9e-2133-4fd0-8606-6b18f1671335',
#          'd9e1aeca-72ac-4c96-977b-bc7a55b34a13',
#          'eead7294-04b3-4ae2-ab36-ccb109b96978',
#          '8b6dd3d3-fb73-48e2-8f57-ac86f2b1170a',
#          'dfac417d-50fc-461f-9862-7fe0593325af',
#          '33cd10a5-3b9a-427c-9ae6-63e96f456227',
#          'eb56cd82-5f88-4c5b-984d-2f61255a34fa',
#          '78acafa6-1564-4c43-a109-8dbce3363f5b',
#          '9f7797de-6220-49a4-87f0-39623a8ccaa5',
#          'b29cc4e3-aca2-492f-bb07-11b621d5ad47',
#          'edd9d6fe-65dd-4119-a02c-dee466823f9f',
#          '93a65e80-a820-4f49-8091-6640709ac7ad',
#          '3d0a1936-87de-4a22-b5fd-68e3919a10e8',
#          'b5872721-b018-4e0e-8232-554ed2fe88ec',
#          '60025a50-d04f-4796-b49c-9c95389cc83e',
#          'd4391a35-d283-4e37-ba57-2114d5f7f853',
#          '2f8e9ef2-7af3-4fe6-a460-bf4909922cd4',
#          '04e6ba00-a829-475c-89af-9d489e8be028',
#          '679eb124-94fd-4bdd-998a-440e82153f24',
#          '726dc5be-8efc-4267-97e1-b0f612d9c41a',
#          '3c23436b-57cd-48dc-b1f3-c2600a69c0ac',
#          '7cda5217-9af4-4c55-8750-f4717699a54b',
#          'ab6c8a16-27f8-4919-967d-145468315489',
#          '639619db-83ad-4ffc-ac33-4f22e4b57a0d',
#          '7fa81bce-0e9d-46be-80c9-675d609964ea',
#          '9fc30e83-a018-473d-8a38-960751e1e7ec',
#          'b08b6bbd-a9f4-44e8-9356-5bb4805b44f9',
#          '9fb9a46f-d857-483c-b7da-a94676691c1c',
#          '03850143-6fca-4cc8-8f17-95ae4eca0fa9',
#          'b8691093-cfe6-4f76-8242-04e98675ba69'],
#  'included': ['documents', 'embeddings', 'metadatas'],
#  'metadatas': [{'chunk_index': 0, 'source': 'Overview'},
#                {'chunk_index': 1, 'source': 'Overview'},
#                {'chunk_index': 2, 'source': 'Overview'},
#                {'chunk_index': 3, 'source': 'Overview'},
#                {'chunk_index': 4, 'source': 'Overview'},
#                {'chunk_index': 5, 'source': 'Overview'},
#                {'chunk_index': 6, 'source': 'Overview'},
#                {'chunk_index': 7, 'source': 'Overview'},
#                {'chunk_index': 0, 'source': 'Education'},
#                {'chunk_index': 1, 'source': 'Education'},
#                {'chunk_index': 2, 'source': 'Education'},
#                {'chunk_index': 3, 'source': 'Education'},
#                {'chunk_index': 4, 'source': 'Education'},
#                {'chunk_index': 5, 'source': 'Education'},
#                {'chunk_index': 6, 'source': 'Education'},
#                {'chunk_index': 7, 'source': 'Education'},
#                {'chunk_index': 8, 'source': 'Education'},
#                {'chunk_index': 9, 'source': 'Education'},
#                {'chunk_index': 10, 'source': 'Education'},
#                {'chunk_index': 11, 'source': 'Education'},
#                {'chunk_index': 0, 'source': 'Professional Experience'},
#                {'chunk_index': 1, 'source': 'Professional Experience'},
#                {'chunk_index': 2, 'source': 'Professional Experience'},
#                {'chunk_index': 3, 'source': 'Professional Experience'},
#                {'chunk_index': 4, 'source': 'Professional Experience'},
#                {'chunk_index': 5, 'source': 'Professional Experience'},
#                {'chunk_index': 6, 'source': 'Professional Experience'},
#                {'chunk_index': 7, 'source': 'Professional Experience'},
#                {'chunk_index': 8, 'source': 'Professional Experience'},
#                {'chunk_index': 9, 'source': 'Professional Experience'},
#                {'chunk_index': 10, 'source': 'Professional Experience'},
#                {'chunk_index': 11, 'source': 'Professional Experience'},
#                {'chunk_index': 12, 'source': 'Professional Experience'},
#                {'chunk_index': 13, 'source': 'Professional Experience'},
#                {'chunk_index': 14, 'source': 'Professional Experience'},
#                {'chunk_index': 15, 'source': 'Professional Experience'}],
#  'uris': None}

# %%
#Tesst retrieval

#Generate embedding for a test query
test_query = "university"

#Embed the query using the same model we used for the chunks to ensure compatibility
#Tip: you will need to convert the query into a list before passing it in
#...
response = client.embeddings.create(
    model="text-embedding-3-small",
    input=[test_query]
)

query_embedding = response.data[0].embedding

#Search ChromaDB
#Tip: use collection.query()
#Tip: you will need to convert the query embedding into a list before passing it in
#...
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=3
)

#Verify retrieval works - print which chunks were retrieved and their content
print(f"***Query: {test_query}")
print("***Retrieved Chunks:")
#for chunk, metadata in ...
for a, b in zip(results["documents"][0], results["metadatas"][0]):
    print(f"<<Document {b['source']} -- Chunk {b['chunk_index']}:\n{a}\n")
# Out:
# ***Query: university
# ***Retrieved Chunks:
# <<Document Education -- Chunk 1:
# oper
# and never looked back!
#
# College: Tecnológico de Monterrey
# B. A. in Animation and Digital Arts, Animation and Digital Arts
# From 2011 – 2015
# Grade: 9.1 of 10
#
# <<Document Education -- Chunk 2:
# 2011 – 2015
# Grade: 9.1 of 10
#
# The Bachelor on Animation and Digital Arts or LAD is a comprehensive program designed to
# merge technology, narrative storytelling, and visual arts.Ranked as the #1 animation program
#
# <<Document Education -- Chunk 8:
# xperience/Interfaces (UX/UI).
# - Post-Production: Sound Design, Visual Effects (VFX), Digital Modeling, and Lighting.
# - Film & Business: Film Production and Direction, Creative Writing, and Entrepreneurship in the Creative Industries.

# %% [markdown]
# ### Step 3: Prepare the list of tools for the LLM

# %%
tools = []

# %% [markdown]
# ### Step 3a: Add tool-calling functionality (Pushover)

# %%
PUSHOVER_USER = os.getenv("PUSHOVER_USER")
PUSHOVER_TOKEN = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

#Create send_notification function

def send_notification(message: str):
    payload = {"user": PUSHOVER_USER, "token": PUSHOVER_TOKEN, "message": message}
    requests.post(pushover_url, data=payload)

#Describe Pushover as an LLM tool
send_notification_function = {
    "name": "send_notification",
    "description": "Sends a push notification to the real-world of you via Pushover on mobile. Use this if the user needs to alert the real-world version of you.",
    "parameters": {
        "type": "object",
        "properties": {
            "message": {
                "type": "string",
                "description": "The notification message to send to the user's device."
            }
        },
        "required": ["message"]
    }
}

#Add Pushover to the list of tools for the LLM
tools.append({"type": "function", "function": send_notification_function})

# %% [markdown]
# ### Step 3b: Add Dice-Rolling functionality

# %%
#Simulates rolling a single six-sided die
def dice_roll():
    result = random.randint(1,6)
    return result

#Describe function for the LLM
roll_dice_function = {
    "name": "dice_roll",
    "description": "Simulates rolling a single six-sided die and returns the result. Use this when the user wants to roll a die for games, decisions, or random number generation.",
    "parameters": {
        "type": "object",
        "properties": {},
        "required": []
    }
}

#Add function to lit of tools of LLM
tools.append({"type": "function", "function": roll_dice_function})

# %% [markdown]
# ### Step 4: Function to handle LLM Tool calls

# %%
def handle_tool_call(tool_calls):
    tool_results = []

    for tool_call in tool_calls:
        function_name = tool_call.function.name
        args = json.loads(tool_call.function.arguments)
        #print(f"Calling function {function_name}") #For future debugging!

        #Route to the appropriate function based on function_name
        if function_name == "send_notification":
            send_notification(args["message"])
            content = f"Notification sent: {args['message']}"
        elif function_name == "dice_roll":
            content = f"Rolled: {dice_roll()}"
        #elif function_name == "insert_function_name_3":
            # content = insert_function_name3(args["message"])
        #....
        else:
            content = f"Unknown function: {function_name}"

        tool_call_result = {
            "role": "tool",
            "content": content,
            "tool_call_id": tool_call.id,
        }

        tool_results.append(tool_call_result)
    
    return tool_results

# %% [markdown]
# ### Step 5: Function to Process the Conversation Turn

# %%
system_message = """You are a digital twin of Andrea Gosset Soto. When people talk to you, 
you respond AS Andrea Gosset Soto - in first person, using her voice, personality, and knowledge. 
Start your very first message as: "Hi there! I'm Andrea" and go on with your regular message.

Important: d not make things up. If you don't know an answer, say you don't know.
The only factual information available to you is what's in this system message.
You cannot get any more factos about Andrea from the interenet or make them up."""

# %%
def response_ai(message, history):
    #RAG
    #Embed the query using the same model we used for the chunks to ensure compatibility
    response = client.embeddings.create(
        model="text-embedding-3-small",
        input=[message]
    )

    query_embedding = response.data[0].embedding

    #Search ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=3
    )

    #Stich retrieve chunks together to create the context for the response
    context = "\n---\n".join(results["documents"][0])
    print("\n========================\n")
    print(f"User message: \n{message}\n")
    print("***Retrieved Chunks:")
    for a, b in zip(results["documents"][0], results["metadatas"][0]):
        print("---------------------")
        print(f"<<Document {b['source']} -- Chunk {b['chunk_index']}:\n{a}\n")

    #Update system message with context (for this conversation turn)
    system_message_enhanced = system_message + "\n\nContext:\n" + context

    #As usual
    messages = [{"role": "system", "content": system_message_enhanced}] + history + [{"role": "user", "content": message}]
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages,
        tools=tools
    )

    message = response.choices[0].message
    reply = response.choices[0].message.content

    while message.tool_calls:
        from pprint import pprint
        pprint(message.tool_calls)
        tools_result = handle_tool_call(message.tool_calls)
        messages.append(message)
        messages.extend(tools_result)
        response = client.chat.completions.create(
            model="gpt-4.1-mini",
            messages=messages,
            tools=tools
        )
        message = response.choices[0].message

        #Note: maybe consider adding protection from infinite consecutive tool calling
        
    return(message.content)

# %% [markdown]
# ### Step 6: Launch Gradio

# %%
gr.ChatInterface(fn=response_ai).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ========================
#
# User message:
# hi there
#
# ***Retrieved Chunks:
# ---------------------
# <<Document Professional Experience -- Chunk 14:
# n within the front-end team.
#
# Technical Skills:
# Javascript (ES6+), React.js, Typescript, Next.js, Angular 7, Vue, jQuery, Jest, Jasmine, Cypress,
# Redux, NgRx, HTML/CSS, Mustache, Handlebars, SASS, MUI, Tailwind, Apollo GraphQL, REST APIs, n8n,
#
# ---------------------
# <<Document Overview -- Chunk 3:
# ad and thinking as a mentor.
#
# Communication style: Friendly and accessible, thinking as a mentor.
#
# Additional info:
# - Andrea is not currently working in anything related to Animation and Digital Arts. She graduated on 2015
#
# ---------------------
# <<Document Professional Experience -- Chunk 1:
# ous learning, and optimizing
# user experience through modern technologies.
# 2015: Intern at MetaCube as a 3D Digital Modeller for the Dia de Muertos movie
# 2016-2018: Front End Engineer at Base22
# 2018-2022: Senior Front End Engineer at Globant
#
#
# ========================
#
# User message:
# what did you study at college?
#
# ***Retrieved Chunks:
# ---------------------
# <<Document Education -- Chunk 1:
# oper
# and never looked back!
#
# College: Tecnológico de Monterrey
# B. A. in Animation and Digital Arts, Animation and Digital Arts
# From 2011 – 2015
# Grade: 9.1 of 10
#
# ---------------------
# <<Document Education -- Chunk 4:
# teractive
# media industries.
#
# Core Pillars of the Curriculum
# The career is structured around three foundational areas:Art & Design: Mastering aesthetics,
# character design, anatomy, digital drawing, and sculpture.Technology & Innovation: Utilizing
#
# ---------------------
# <<Document Education -- Chunk 6:
# directing, and sound design.
#
# Areas of Specialization (Concentrations)
# Rather than focusing solely on one style, Tec de Monterrey offers sixteen distinct disciplinary
# concentrations to let students customize their career paths. Students can specialize in fields such
# as:
#
#
# ========================
#
# User message:
# are you still working on digital animation and arts?
#
# ***Retrieved Chunks:
# ---------------------
# <<Document Education -- Chunk 1:
# oper
# and never looked back!
#
# College: Tecnológico de Monterrey
# B. A. in Animation and Digital Arts, Animation and Digital Arts
# From 2011 – 2015
# Grade: 9.1 of 10
#
# ---------------------
# <<Document Education -- Chunk 0:
# Disclamer: Andrea is not currently working in anything related to Animation and Digital Arts.
# She graduated on 2015 and 3 months after that she took her first job as a Front End Developer
# and never looked back!
#
# ---------------------
# <<Document Education -- Chunk 7:
# pecialize in fields such
# as:
# - Animation Styles: 2D Animation, 3D Character Animation, and Stop Motion.
# - Gaming & Interactivity: Video Game Design, Immersive Environments, and User Experience/Interfaces (UX/UI).
#
#
# ========================
#
# User message:
# tell me about Andrea's professional life
#
# ***Retrieved Chunks:
# ---------------------
# <<Document Overview -- Chunk 4:
# l Arts. She graduated on 2015
#     and 3 months after that she took her first job as a Front End Developer and never looked back!
# - In 2008 Andrea was studying highshool abroad
# - Andrea doesn't like cooking
#
# ---------------------
# <<Document Overview -- Chunk 0:
# Andrea is an experienced Front End Engineer. She's based in Atlanta, Georgia. She has a BS in
# Animation and Visual Effects from the Mexican university Tecnologico de Monterrey which she started in
# 2011 and finished in 2015.
#
# ---------------------
# <<Document Education -- Chunk 0:
# Disclamer: Andrea is not currently working in anything related to Animation and Digital Arts.
# She graduated on 2015 and 3 months after that she took her first job as a Front End Developer
# and never looked back!
